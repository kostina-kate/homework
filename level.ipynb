# %% [markdown]
# <a href="https://colab.research.google.com/github/kostina-kate/homework/blob/task-one/level.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
experience = 2

if experience < 1:
    print('младший аналитик')

elif experience >= 1 and experience < 5:
    print('аналитик')

else:
    print('старший аналитик')
# Out:
# аналитик
